# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
diabetes_df = pd.read_csv("/Users/sonia_ij/Desktop/Data Analysis Class/Module 19/Neural_Networks_and_Deep_Learning_Models/Resources/diabetes.csv")
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Convert y_test and y_train to ndarrays
y_test = np.array(y_test)
y_train = np.array(y_train)

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Train on 576 samples
# Epoch 1/100
# 576/576 [==============================] - 1s 1ms/sample - loss: 0.7467 - accuracy: 0.5174
# Epoch 2/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.6952 - accuracy: 0.5694
# Epoch 3/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.6554 - accuracy: 0.6198
# Epoch 4/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.6244 - accuracy: 0.6580
# Epoch 5/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.5981 - accuracy: 0.6979
# Epoch 6/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.5778 - accuracy: 0.7153
# Epoch 7/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.5604 - accuracy: 0.7309
# Epoch 8/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.5452 - accuracy: 0.7344
# Epoch 9/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.5326 - accuracy: 0.7500
# Epoch 10/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.5216 - accuracy: 0.7569
# Epoch 11/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.5123 - accuracy: 0.7604
# Epoch 12/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.5044 - accuracy: 0.7639
# Epoch 13/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4967 - accuracy: 0.7622
# Epoch 14/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4901 - accuracy: 0.7656
# Epoch 15/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4844 - accuracy: 0.7691
# Epoch 16/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4789 - accuracy: 0.7847
# Epoch 17/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4743 - accuracy: 0.7865
# Epoch 18/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4701 - accuracy: 0.7830
# Epoch 19/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4660 - accuracy: 0.7795
# Epoch 20/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4629 - accuracy: 0.7847
# Epoch 21/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4598 - accuracy: 0.7865
# Epoch 22/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4570 - accuracy: 0.7882
# Epoch 23/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4543 - accuracy: 0.7899
# Epoch 24/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4521 - accuracy: 0.7899
# Epoch 25/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4501 - accuracy: 0.7969
# Epoch 26/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4480 - accuracy: 0.7986
# Epoch 27/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4462 - accuracy: 0.8003
# Epoch 28/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4445 - accuracy: 0.8003
# Epoch 29/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4435 - accuracy: 0.8003
# Epoch 30/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4419 - accuracy: 0.8003
# Epoch 31/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4404 - accuracy: 0.8038
# Epoch 32/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4391 - accuracy: 0.8056
# Epoch 33/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4382 - accuracy: 0.8038
# Epoch 34/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4372 - accuracy: 0.8021
# Epoch 35/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4361 - accuracy: 0.8038
# Epoch 36/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4355 - accuracy: 0.8056
# Epoch 37/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4347 - accuracy: 0.8056
# Epoch 38/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4338 - accuracy: 0.8038
# Epoch 39/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4328 - accuracy: 0.8038
# Epoch 40/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4327 - accuracy: 0.8038
# Epoch 41/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4317 - accuracy: 0.8038
# Epoch 42/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4311 - accuracy: 0.8038
# Epoch 43/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4308 - accuracy: 0.8090
# Epoch 44/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4296 - accuracy: 0.8056
# Epoch 45/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4288 - accuracy: 0.8090
# Epoch 46/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4288 - accuracy: 0.8090
# Epoch 47/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4277 - accuracy: 0.8108
# Epoch 48/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4271 - accuracy: 0.8108
# Epoch 49/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4266 - accuracy: 0.8125
# Epoch 50/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4258 - accuracy: 0.8125
# Epoch 51/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4254 - accuracy: 0.8108
# Epoch 52/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4250 - accuracy: 0.8142
# Epoch 53/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4243 - accuracy: 0.8142
# Epoch 54/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4241 - accuracy: 0.8108
# Epoch 55/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4235 - accuracy: 0.8142
# Epoch 56/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4229 - accuracy: 0.8125
# Epoch 57/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4226 - accuracy: 0.8142
# Epoch 58/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4221 - accuracy: 0.8108
# Epoch 59/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4215 - accuracy: 0.8090
# Epoch 60/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4214 - accuracy: 0.8108
# Epoch 61/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4210 - accuracy: 0.8090
# Epoch 62/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4206 - accuracy: 0.8090
# Epoch 63/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4204 - accuracy: 0.8108
# Epoch 64/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4198 - accuracy: 0.8108
# Epoch 65/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4192 - accuracy: 0.8108
# Epoch 66/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4193 - accuracy: 0.8125
# Epoch 67/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4187 - accuracy: 0.8125
# Epoch 68/100
# 576/576 [==============================] - 0s 70us/sample - loss: 0.4182 - accuracy: 0.8142
# Epoch 69/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4181 - accuracy: 0.8125
# Epoch 70/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4176 - accuracy: 0.8125
# Epoch 71/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4172 - accuracy: 0.8125
# Epoch 72/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4170 - accuracy: 0.8108
# Epoch 73/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4165 - accuracy: 0.8125
# Epoch 74/100
# 576/576 [==============================] - 0s 69us/sample - loss: 0.4163 - accuracy: 0.8125
# Epoch 75/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4161 - accuracy: 0.8108
# Epoch 76/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4157 - accuracy: 0.8125
# Epoch 77/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4153 - accuracy: 0.8108
# Epoch 78/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4153 - accuracy: 0.8125
# Epoch 79/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4146 - accuracy: 0.8108
# Epoch 80/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4142 - accuracy: 0.8108
# Epoch 81/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4140 - accuracy: 0.8125
# Epoch 82/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4137 - accuracy: 0.8142
# Epoch 83/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4133 - accuracy: 0.8160
# Epoch 84/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4131 - accuracy: 0.8125
# Epoch 85/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4128 - accuracy: 0.8125
# Epoch 86/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4131 - accuracy: 0.8125
# Epoch 87/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4126 - accuracy: 0.8142
# Epoch 88/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4120 - accuracy: 0.8142
# Epoch 89/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4121 - accuracy: 0.8142
# Epoch 90/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4115 - accuracy: 0.8160
# Epoch 91/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4112 - accuracy: 0.8142
# Epoch 92/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4110 - accuracy: 0.8108
# Epoch 93/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4106 - accuracy: 0.8142
# Epoch 94/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4108 - accuracy: 0.8108
# Epoch 95/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4107 - accuracy: 0.8090
# Epoch 96/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4098 - accuracy: 0.8125
# Epoch 97/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4097 - accuracy: 0.8142
# Epoch 98/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4094 - accuracy: 0.8125
# Epoch 99/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4097 - accuracy: 0.8125
# Epoch 100/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4098 - accuracy: 0.8142
# 192/1 - 0s - loss: 0.5528 - accuracy: 0.7292
# Loss: 0.5184566279252371, Accuracy: 0.7291666865348816
